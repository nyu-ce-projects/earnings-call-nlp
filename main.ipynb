# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Academics/NLP/earnings-call-nlp
# !pip install transformers datasets

# %%
from transformers import BertTokenizer
from Datasets.FIQA_SA import FIQA_SA
from Datasets.FIQA_Aspect import FIQA_Aspect
from Models.FinBERT_SA import FinBERT_SA
from Models.FinBERT_Aspect import FinBERT_Aspect
from Datasets.HFDataset import HFDataset
from datasets import Dataset

# %%
import torch
import os

# %%
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-pretrain')

# %% [markdown]
# ## Sentiment Analysis

# %%
# Instance created
fiqa_sa_data = FIQA_SA(tokenizer)
# __call__ method will be called
train_fiqa_sa, test_fiqa_sa  = fiqa_sa_data()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
train_fiqa_sa, test_fiqa_sa = HFDataset(train_fiqa_sa), HFDataset(test_fiqa_sa)
model = FinBERT_SA()
model.train(train_fiqa_sa, test_fiqa_sa)
# Out:
# Downloading:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 999
#   Num Epochs = 5
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 160
#   Number of trainable parameters = 109754115
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 05:29, Epoch 5/5]
#     </div>
# ...

# %%
precision, recall, fscore = model.get_precision_recall()
print("Precision: {:3f}, Recall: {:3f}, F1_weighted: {:3f}".format(precision, recall, fscore))
# Out:
# Precision: 0.677144, Recall: 0.676786, F1_weighted: 0.672084

# %% [markdown]
# ## Aspect Detection

# %%
# Instance created
fiqa_ad_data = FIQA_Aspect(tokenizer)
# __call__ method will be called
train_fiqa_ad, test_fiqa_ad  = fiqa_ad_data()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
#Define model
model_ad = FinBERT_Aspect()
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--yiyanghkust--finbert-pretrain/snapshots/88ab954a39ea6d3ce2b62cff086dd5ad1172c664/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.25.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30873
# }
#
# ...

# %%
train_fiqa_ad, test_fiqa_ad = HFDataset(train_fiqa_ad), HFDataset(test_fiqa_ad)

# %%
model_ad.train(train_fiqa_ad, test_fiqa_ad)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 999
#   Num Epochs = 5
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 160
#   Number of trainable parameters = 109754115
#     <div>
#
# ...

# %%
precision_ad, recall_ad, fscore_ad = model_ad.get_precision_recall()
print("Precision: {:3f}, Recall: {:3f}, F1_weighted: {:3f}".format(precision_ad, recall_ad, fscore_ad))
# Out:
# Precision: 0.648948, Recall: 0.641071, F1_weighted: 0.632909

# %%
#@title Sentiment Analysis Prediction
#model = model.to('cpu')
Input_text = 'Share prices shot up as company has gained millions of new users' #@param {type:"string"}
prediction = model.checkSentiment(Input_text, device = -1)

print(prediction)
# Out:
# Keyword arguments {'device': -1} not recognized.
# [{'label': 'Positive', 'score': 0.9607407450675964}]

# %%
#@title Aspect Class Prediction
#model = model.to('cpu')
Input_text = 'Share prices shot up as company has gained millions of new users' #@param {type:"string"}
prediction_ad = model_ad.detect_aspect(Input_text, device = -1)

print(prediction_ad)
# Out:
# Keyword arguments {'device': -1} not recognized.
# [{'label': 'LABEL_1', 'score': 0.7440634965896606}]
