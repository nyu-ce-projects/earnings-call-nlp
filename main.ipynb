# %%
#from google.colab import drive
#drive.mount('/content/drive')
#%cd drive/MyDrive/Academics/NLP/earnings-call-nlp
#!pip install transformers datasets
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/Academics/NLP/earnings-call-nlp'
# /content/drive/MyDrive/Academics/NLP/earnings-call-nlp

# %%
from transformers import BertTokenizer
from Datasets.FIQA_SA import FIQA_SA
from Models.FinBERT_SA import FinBERT_SA

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased') 
# Instance created
e = FIQA_SA(tokenizer)
  
# __call__ method will be called
train, test  = e()
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
from torch.utils.data import Dataset
 
class HFDataset(Dataset):
    def __init__(self, dset):
        self.dset = dset

    def __getitem__(self, idx):
        return self.dset[idx]

    def __len__(self):
        return len(self.dset)

train_ds = HFDataset(train)
test_ds = HFDataset(test)

# %%
model = FinBERT_SA()
# Out:
# Downloading:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
model.train(train_ds, test_ds)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 999
#   Num Epochs = 5
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 160
#   Number of trainable parameters = 109754115
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 02:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.127200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.046856</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.092406</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.122320</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.121356</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 112
#   Batch size = 32
# Saving model checkpoint to /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-32
# Configuration saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-32/config.json
# Model weights saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-32/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 112
#   Batch size = 32
# Saving model checkpoint to /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-64
# Configuration saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-64/config.json
# Model weights saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-64/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 112
#   Batch size = 32
# Saving model checkpoint to /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-96
# Configuration saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-96/config.json
# Model weights saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-96/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 112
#   Batch size = 32
# Saving model checkpoint to /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-128
# Configuration saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-128/config.json
# Model weights saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-128/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 112
#   Batch size = 32
# Saving model checkpoint to /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-160
# Configuration saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-160/config.json
# Model weights saved in /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-160/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/drive/MyDrive/Academics/NLP/earnings-call-nlp/finetuned_models/sentiment_analysis/checkpoint-64 (score: 1.0468556880950928).
